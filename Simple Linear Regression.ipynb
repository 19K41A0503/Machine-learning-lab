# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salary_Data.csv')
x = data['YearsExperience']
y = data['Salary']

# %%
print(data.head())
print(data.tail())
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
def linear_regression(x, y):     
    N = len(x)
    x_mean = x.mean()
    y_mean = y.mean()
    
    B1_num = ((x - x_mean) * (y - y_mean)).sum()
    B1_den = ((x - x_mean)**2).sum()
    B1 = B1_num / B1_den
    
    B0 = y_mean - (B1*x_mean)
   # print('hghjgjh',B1_num)
   
    reg_line = 'y = {} + {}β'.format(B0, round(B1, 3))
    
    return (B0, B1, reg_line)

# %%
#print("hghjgjh")

# %%
N = len(x)
x_mean = x.mean()
y_mean = y.mean()

print(N)
# Out:
# 30

# %%
B1_num = ((x - x_mean) * (y - y_mean)).sum()
B1_den = ((x - x_mean)**2).sum()
B1 = B1_num / B1_den
print(B1)
# Out:
# 9449.962321455077

# %%
B0 = y_mean - (B1 * x_mean)
print (B0)
# Out:
# 25792.20019866869

# %%
def corr_coef(x, y):
    N = len(x)
    num = (N * (x*y).sum()) - (x.sum() * y.sum())
    den = np.sqrt((N * (x**2).sum() - x.sum()**2) * (N * (y**2).sum() - y.sum()**2))
    R = num / den
    return R
print(x.sum())
print(y.sum())
# Out:
# 159.4
# 2280090

# %%
B0, B1, reg_line = linear_regression(x, y)
print('Regression Line: ', reg_line)
R = corr_coef(x, y)
print('Correlation Coef.: ', R)
print('"Goodness of Fit": ', R**2)
# Out:
# Regression Line:  y = 25792.20019866869 + 9449.962β
# Correlation Coef.:  0.97824161848876
# "Goodness of Fit":  0.9569566641435087

# %%
plt.figure(figsize=(12,5))
plt.scatter(x, y, s=30, linewidths=1, edgecolor='black')
text = '''X Mean: {} Years
Y Mean: ${}
R: {}
R^2: {}
y = {} + {}X'''.format(round(x.mean(), 2), 
                       round(y.mean(), 2), 
                       round(R, 4), 
                       round(R**2, 4),
                       round(B0, 3),
                       round(B1, 3))
plt.text(x=1, y=100000, s=text, fontsize=12, bbox={'facecolor': 'grey', 'alpha': 0.2, 'pad': 10})
plt.title('How Experience Affects Salary')
plt.xlabel('Years of Experience', fontsize=15)
plt.ylabel('Salary', fontsize=15)
plt.plot(x, B0 + B1*x, c = 'r', linewidth=8, alpha=.5, solid_capstyle='round')
plt.scatter(x=x.mean(), y=y.mean(), marker='+', s=10**2.5, c='r') # average point

# %%
def predicted(B0, B1, new_x):
    y = B0 + B1 * new_x
    return y
print (y)
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64
